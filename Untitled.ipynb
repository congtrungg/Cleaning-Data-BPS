# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print (os.listdir())
# Out:
# ['.ipynb_checkpoints', 'DATA.xlsx', 'Untitled.ipynb']

# %%
df = pd.read_excel("DATA.xlsx")

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1         Unnamed: 2                Unnamed: 3  \
# 0            NaN          NaN                NaN                       NaN
# 1            NaN  Customer ID      Customer Name                   Address
# 2            NaN            1  Gabriele McLernon          48993 East Plaza
# 3            NaN            2    Latisha Bendley           936 2nd Parkway
# 4            NaN            3      Cordie Tuther           6 Dapin Parkway
# ...          ...          ...                ...                       ...
# 997          NaN          996    Eloisa McCotter     86784 Starling Center
# 998          NaN          997       Marcia Elgey  56064 Graceland Junction
# 999          NaN          998       Maje Ockland             4 Ryan Circle
# 1000         NaN          999    Sukey Hickisson            30 Summit Road
# 1001         NaN         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                        Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7
# 0                             NaN        NaN           NaN        NaN
# 1                           Email     Gender         Phone  Region ID
# 2        gmclernon0@google.com.au       Male  180-880-9744          1
# 3           lbendley1@tinyurl.com     Female  445-983-5808          2
# 4           ctuther2@springer.com     Female  441-987-5306          3
# ...                           ...        ...           ...        ...
# 997   emccotterrn@sourceforge.net     Female  636-384-2022         51
# 998           melgeyro@oakley.com     Female  783-597-1803         52
# 999           mocklandrp@ox.ac.uk       Male  691-787-8988         53
# 1000       shickissonrq@jigsy.com     Female  465-853-8927         54
# 1001       kgrimwadrr@twitter.com     Female  429-792-7151         55
#
# [1002 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    1002
# Unnamed: 1       1
# Unnamed: 2       1
# Unnamed: 3       1
# Unnamed: 4       1
# Unnamed: 5       1
# Unnamed: 6       1
# Unnamed: 7       1
# dtype: int64

# %%
missing_value=["N/a", "na", np.nan]
df = pd.read_excel("DATA.xlsx", na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    1002
# Unnamed: 1       1
# Unnamed: 2       1
# Unnamed: 3       1
# Unnamed: 4       1
# Unnamed: 5       1
# Unnamed: 6       1
# Unnamed: 7       1
# dtype: int64

# %%
df.isnull().any()
# Out:
# Unnamed: 0    True
# Unnamed: 1    True
# Unnamed: 2    True
# Unnamed: 3    True
# Unnamed: 4    True
# Unnamed: 5    True
# Unnamed: 6    True
# Unnamed: 7    True
# dtype: bool

# %%
df.dropna(how="all")
# Out:
#       Unnamed: 0   Unnamed: 1         Unnamed: 2                Unnamed: 3  \
# 1            NaN  Customer ID      Customer Name                   Address
# 2            NaN            1  Gabriele McLernon          48993 East Plaza
# 3            NaN            2    Latisha Bendley           936 2nd Parkway
# 4            NaN            3      Cordie Tuther           6 Dapin Parkway
# 5            NaN            4     Nicolas Pregal        4 Kensington Place
# ...          ...          ...                ...                       ...
# 997          NaN          996    Eloisa McCotter     86784 Starling Center
# 998          NaN          997       Marcia Elgey  56064 Graceland Junction
# 999          NaN          998       Maje Ockland             4 Ryan Circle
# 1000         NaN          999    Sukey Hickisson            30 Summit Road
# 1001         NaN         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                        Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7
# 1                           Email     Gender         Phone  Region ID
# 2        gmclernon0@google.com.au       Male  180-880-9744          1
# 3           lbendley1@tinyurl.com     Female  445-983-5808          2
# 4           ctuther2@springer.com     Female  441-987-5306          3
# 5          npregal3@wikimedia.org       Male  880-129-2534          4
# ...                           ...        ...           ...        ...
# 997   emccotterrn@sourceforge.net     Female  636-384-2022         51
# 998           melgeyro@oakley.com     Female  783-597-1803         52
# 999           mocklandrp@ox.ac.uk       Male  691-787-8988         53
# 1000       shickissonrq@jigsy.com     Female  465-853-8927         54
# 1001       kgrimwadrr@twitter.com     Female  429-792-7151         55
#
# [1001 rows x 8 columns]

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7]
# Index: []

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0   Unnamed: 1         Unnamed: 2                Unnamed: 3  \
# 0            NaN          NaN                NaN                       NaN
# 1            NaN  Customer ID      Customer Name                   Address
# 2            NaN            1  Gabriele McLernon          48993 East Plaza
# 3            NaN            2    Latisha Bendley           936 2nd Parkway
# 4            NaN            3      Cordie Tuther           6 Dapin Parkway
# ...          ...          ...                ...                       ...
# 997          NaN          996    Eloisa McCotter     86784 Starling Center
# 998          NaN          997       Marcia Elgey  56064 Graceland Junction
# 999          NaN          998       Maje Ockland             4 Ryan Circle
# 1000         NaN          999    Sukey Hickisson            30 Summit Road
# 1001         NaN         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                        Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7
# 0                             NaN        NaN           NaN        NaN
# 1                           Email     Gender         Phone  Region ID
# 2        gmclernon0@google.com.au       Male  180-880-9744          1
# 3           lbendley1@tinyurl.com     Female  445-983-5808          2
# 4           ctuther2@springer.com     Female  441-987-5306          3
# ...                           ...        ...           ...        ...
# 997   emccotterrn@sourceforge.net     Female  636-384-2022         51
# 998           melgeyro@oakley.com     Female  783-597-1803         52
# 999           mocklandrp@ox.ac.uk       Male  691-787-8988         53
# 1000       shickissonrq@jigsy.com     Female  465-853-8927         54
# 1001       kgrimwadrr@twitter.com     Female  429-792-7151         55
#
# [1002 rows x 8 columns]

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1         Unnamed: 2                Unnamed: 3  \
# 0            NaN          NaN                NaN                       NaN
# 1            NaN  Customer ID      Customer Name                   Address
# 2            NaN            1  Gabriele McLernon          48993 East Plaza
# 3            NaN            2    Latisha Bendley           936 2nd Parkway
# 4            NaN            3      Cordie Tuther           6 Dapin Parkway
# ...          ...          ...                ...                       ...
# 997          NaN          996    Eloisa McCotter     86784 Starling Center
# 998          NaN          997       Marcia Elgey  56064 Graceland Junction
# 999          NaN          998       Maje Ockland             4 Ryan Circle
# 1000         NaN          999    Sukey Hickisson            30 Summit Road
# 1001         NaN         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                        Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7
# 0                             NaN        NaN           NaN        NaN
# 1                           Email     Gender         Phone  Region ID
# 2        gmclernon0@google.com.au       Male  180-880-9744          1
# 3           lbendley1@tinyurl.com     Female  445-983-5808          2
# 4           ctuther2@springer.com     Female  441-987-5306          3
# ...                           ...        ...           ...        ...
# 997   emccotterrn@sourceforge.net     Female  636-384-2022         51
# 998           melgeyro@oakley.com     Female  783-597-1803         52
# 999           mocklandrp@ox.ac.uk       Male  691-787-8988         53
# 1000       shickissonrq@jigsy.com     Female  465-853-8927         54
# 1001       kgrimwadrr@twitter.com     Female  429-792-7151         55
#
# [1002 rows x 8 columns]

# %%
df = pd.read_excel("DATA.xlsx")

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1         Unnamed: 2                Unnamed: 3  \
# 0            NaN          NaN                NaN                       NaN
# 1            NaN  Customer ID      Customer Name                   Address
# 2            NaN            1  Gabriele McLernon          48993 East Plaza
# 3            NaN            2    Latisha Bendley           936 2nd Parkway
# 4            NaN            3      Cordie Tuther           6 Dapin Parkway
# ...          ...          ...                ...                       ...
# 997          NaN          996    Eloisa McCotter     86784 Starling Center
# 998          NaN          997       Marcia Elgey  56064 Graceland Junction
# 999          NaN          998       Maje Ockland             4 Ryan Circle
# 1000         NaN          999    Sukey Hickisson            30 Summit Road
# 1001         NaN         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                        Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7
# 0                             NaN        NaN           NaN        NaN
# 1                           Email     Gender         Phone  Region ID
# 2        gmclernon0@google.com.au       Male  180-880-9744          1
# 3           lbendley1@tinyurl.com     Female  445-983-5808          2
# 4           ctuther2@springer.com     Female  441-987-5306          3
# ...                           ...        ...           ...        ...
# 997   emccotterrn@sourceforge.net     Female  636-384-2022         51
# 998           melgeyro@oakley.com     Female  783-597-1803         52
# 999           mocklandrp@ox.ac.uk       Male  691-787-8988         53
# 1000       shickissonrq@jigsy.com     Female  465-853-8927         54
# 1001       kgrimwadrr@twitter.com     Female  429-792-7151         55
#
# [1002 rows x 8 columns]

# %%
df = pd.read_excel("DATA.xlsx")
df
# Out:
#      Customer ID      Customer Name                   Address  \
# 0              1  Gabriele McLernon          48993 East Plaza
# 1              2    Latisha Bendley           936 2nd Parkway
# 2              3      Cordie Tuther           6 Dapin Parkway
# 3              4     Nicolas Pregal        4 Kensington Place
# 4              5   Brigg Antognazzi         048 Kipling Alley
# ..           ...                ...                       ...
# 995          996    Eloisa McCotter     86784 Starling Center
# 996          997       Marcia Elgey  56064 Graceland Junction
# 997          998       Maje Ockland             4 Ryan Circle
# 998          999    Sukey Hickisson            30 Summit Road
# 999         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                            Email  Gender         Phone  Region ID
# 0       gmclernon0@google.com.au    Male  180-880-9744          1
# 1          lbendley1@tinyurl.com  Female  445-983-5808          2
# 2          ctuther2@springer.com  Female  441-987-5306          3
# 3         npregal3@wikimedia.org    Male  880-129-2534          4
# 4           bantognazzi4@com.com    Male  550-413-9604          5
# ..                           ...     ...           ...        ...
# 995  emccotterrn@sourceforge.net  Female  636-384-2022         51
# 996          melgeyro@oakley.com  Female  783-597-1803         52
# 997          mocklandrp@ox.ac.uk    Male  691-787-8988         53
# 998       shickissonrq@jigsy.com  Female  465-853-8927         54
# 999       kgrimwadrr@twitter.com  Female  429-792-7151         55
#
# [1000 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Customer ID      0
# Customer Name    0
# Address          0
# Email            0
# Gender           0
# Phone            0
# Region ID        0
# dtype: int64

# %%
missing_value=["N/a", "na", np.nan]
df = pd.read_excel("DATA.xlsx", na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# Customer ID      0
# Customer Name    0
# Address          0
# Email            0
# Gender           0
# Phone            0
# Region ID        0
# dtype: int64

# %%
df = pd.read_excel("DATA.xlsx")
df
# Out:
#      Customer ID      Customer Name                   Address  \
# 0              1  Gabriele McLernon          48993 East Plaza
# 1              2    Latisha Bendley           936 2nd Parkway
# 2              3      Cordie Tuther           6 Dapin Parkway
# 3              4     Nicolas Pregal        4 Kensington Place
# 4              5   Brigg Antognazzi         048 Kipling Alley
# ..           ...                ...                       ...
# 995          996    Eloisa McCotter     86784 Starling Center
# 996          997       Marcia Elgey  56064 Graceland Junction
# 997          998       Maje Ockland             4 Ryan Circle
# 998          999    Sukey Hickisson            30 Summit Road
# 999         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                            Email  Gender         Phone  Region ID
# 0       gmclernon0@google.com.au    Male  180-880-9744          1
# 1          lbendley1@tinyurl.com  Female  445-983-5808          2
# 2          ctuther2@springer.com  Female           NaN          3
# 3         npregal3@wikimedia.org    Male  880-129-2534          4
# 4           bantognazzi4@com.com    Male  550-413-9604          5
# ..                           ...     ...           ...        ...
# 995  emccotterrn@sourceforge.net  Female  636-384-2022         51
# 996          melgeyro@oakley.com  Female  783-597-1803         52
# 997          mocklandrp@ox.ac.uk    Male  691-787-8988         53
# 998       shickissonrq@jigsy.com  Female  465-853-8927         54
# 999       kgrimwadrr@twitter.com  Female  429-792-7151         55
#
# [1000 rows x 7 columns]

# %%
missing_value=["N/a", "na", np.nan]
df = pd.read_excel("DATA.xlsx", na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# Customer ID       0
# Customer Name     0
# Address           0
# Email             0
# Gender            0
# Phone            23
# Region ID         0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Customer ID      False
# Customer Name    False
# Address          False
# Email            False
# Gender           False
# Phone             True
# Region ID        False
# dtype: bool

# %%
df = df.fillna('')
df
# Out:
#      Customer ID      Customer Name                   Address  \
# 0              1  Gabriele McLernon          48993 East Plaza
# 1              2    Latisha Bendley           936 2nd Parkway
# 2              3      Cordie Tuther           6 Dapin Parkway
# 3              4     Nicolas Pregal        4 Kensington Place
# 4              5   Brigg Antognazzi         048 Kipling Alley
# ..           ...                ...                       ...
# 995          996    Eloisa McCotter     86784 Starling Center
# 996          997       Marcia Elgey  56064 Graceland Junction
# 997          998       Maje Ockland             4 Ryan Circle
# 998          999    Sukey Hickisson            30 Summit Road
# 999         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                            Email  Gender         Phone  Region ID
# 0       gmclernon0@google.com.au    Male  180-880-9744          1
# 1          lbendley1@tinyurl.com  Female  445-983-5808          2
# 2          ctuther2@springer.com  Female                        3
# 3         npregal3@wikimedia.org    Male  880-129-2534          4
# 4           bantognazzi4@com.com    Male  550-413-9604          5
# ..                           ...     ...           ...        ...
# 995  emccotterrn@sourceforge.net  Female  636-384-2022         51
# 996          melgeyro@oakley.com  Female  783-597-1803         52
# 997          mocklandrp@ox.ac.uk    Male  691-787-8988         53
# 998       shickissonrq@jigsy.com  Female  465-853-8927         54
# 999       kgrimwadrr@twitter.com  Female  429-792-7151         55
#
# [1000 rows x 7 columns]

# %%
df = df.replace('N/A','')
df = df.replace('NaN','')
df
# Out:
#      Customer ID      Customer Name                   Address  \
# 0              1  Gabriele McLernon          48993 East Plaza
# 1              2    Latisha Bendley           936 2nd Parkway
# 2              3      Cordie Tuther           6 Dapin Parkway
# 3              4     Nicolas Pregal        4 Kensington Place
# 4              5   Brigg Antognazzi         048 Kipling Alley
# ..           ...                ...                       ...
# 995          996    Eloisa McCotter     86784 Starling Center
# 996          997       Marcia Elgey  56064 Graceland Junction
# 997          998       Maje Ockland             4 Ryan Circle
# 998          999    Sukey Hickisson            30 Summit Road
# 999         1000      Kitty Grimwad          0 Mcguire Avenue
#
#                            Email  Gender         Phone  Region ID
# 0       gmclernon0@google.com.au    Male  180-880-9744          1
# 1          lbendley1@tinyurl.com  Female  445-983-5808          2
# 2          ctuther2@springer.com  Female                        3
# 3         npregal3@wikimedia.org    Male  880-129-2534          4
# 4           bantognazzi4@com.com    Male  550-413-9604          5
# ..                           ...     ...           ...        ...
# 995  emccotterrn@sourceforge.net  Female  636-384-2022         51
# 996          melgeyro@oakley.com  Female  783-597-1803         52
# 997          mocklandrp@ox.ac.uk    Male  691-787-8988         53
# 998       shickissonrq@jigsy.com  Female  465-853-8927         54
# 999       kgrimwadrr@twitter.com  Female  429-792-7151         55
#
# [1000 rows x 7 columns]

# %%
sns.heatmap(df.isnull(), yticklabels= False, annot= True)
# Out:
# <Axes: >
